# %%
import pandas as pd 
import numpy as np

# %%
d1=pd.read_csv("Glassdoor_Job_Postings.csv")

# %%
d1
# Out:
#                         company                            job_title  \
# 0                           ABB                  Junior Data Analyst
# 1                       Philips               Data Scientist - AI/ML
# 2                          HSBC                   Data Science GSC’s
# 3             Facctum Solutions                         Data Analyst
# 4           JPMorgan Chase & Co       Data and Analytics - Associate
# ..                          ...                                  ...
# 895              Kpro Solutions             Analytics & Data Science
# 896  Athena Global Technologies                        Data Engineer
# 897                       Wesco       India-Bangalore: Data Engineer
# 898                     Course5                       Data Scientist
# 899                  Sanfoundry  Machine Learning Engineer - Fresher
#
#      company_rating                                    job_description  \
# ...

# %%
d1.isnull().sum()
# Out:
# company                          1
# job_title                        0
# company_rating                 244
# job_description                 12
# location                         0
# salary_avg_estimate            264
# salary_estimate_payperiod      264
# company_size                   126
# company_founded                126
# employment_type                126
# industry                       126
# sector                         126
# revenue                        126
# career_opportunities_rating    169
# comp_and_benefits_rating       169
# culture_and_values_rating      169
# senior_management_rating       169
# work_life_balance_rating       169
# dtype: int64

# %%
d1.dropna(how="all")
# Out:
#                         company                            job_title  \
# 0                           ABB                  Junior Data Analyst
# 1                       Philips               Data Scientist - AI/ML
# 2                          HSBC                   Data Science GSC’s
# 3             Facctum Solutions                         Data Analyst
# 4           JPMorgan Chase & Co       Data and Analytics - Associate
# ..                          ...                                  ...
# 895              Kpro Solutions             Analytics & Data Science
# 896  Athena Global Technologies                        Data Engineer
# 897                       Wesco       India-Bangalore: Data Engineer
# 898                     Course5                       Data Scientist
# 899                  Sanfoundry  Machine Learning Engineer - Fresher
#
#      company_rating                                    job_description  \
# ...

# %%
d1.isnull().sum()
# Out:
# company                          1
# job_title                        0
# company_rating                 244
# job_description                 12
# location                         0
# salary_avg_estimate            264
# salary_estimate_payperiod      264
# company_size                   126
# company_founded                126
# employment_type                126
# industry                       126
# sector                         126
# revenue                        126
# career_opportunities_rating    169
# comp_and_benefits_rating       169
# culture_and_values_rating      169
# senior_management_rating       169
# work_life_balance_rating       169
# dtype: int64
